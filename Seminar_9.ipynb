# %% [markdown]
# <a href="https://colab.research.google.com/github/GodVik53/08.09/blob/main/Seminar_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задача №57.
# # 1. Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# # 2. Посмотреть сколько в нем строк и столбцов
# # 3. Определить какой тип данных имеют столбцы

# %%
import pandas as pd # as - псевдоним

df = pd.read_csv("/content/sample_data/california_housing_test.csv") # пишем путь, какой файл нужно прочиать
df

df.head() # выводит первые 5 строк таблицы, если в скобках не указывать количество выводимых строк. строк д.б. не больше, чем во всей таблице
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df. tail() # выводит строки
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.sample(5) # выводит рандомные строки , в данном случае 5 строк
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1323    -118.05     33.95                33.0       1954.0           390.0
# 215     -122.26     37.55                17.0       4576.0           814.0
# 1576    -118.50     34.19                26.0       2156.0           509.0
# 1327    -122.24     37.81                52.0       2026.0           482.0
# 381     -122.45     37.74                38.0       5688.0           930.0
#
#       population  households  median_income  median_house_value
# 1323      1600.0       376.0         3.6125            170800.0
# 215       1941.0       807.0         5.9572            443800.0
# 1576      1142.0       470.0         4.0000            224700.0
# 1327       709.0       456.0         3.2727            268500.0
# 381       2263.0       908.0         6.2030            346800.0

# %%
df.shape # Посмотреть сколько в нем строк и столбцов (строки, коллоны)
# Out:
# (3000, 9)

# %%
df.dtypes # выдает тип данных в колонках
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.info() # тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# # Задача №59.
# # 1. Проверить есть ли в файле пустые значения

# %%
df.isnull()
df.isna()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# 2. Показать median_house_value где median_income < 2

# %%
df[df["median_income"] < 2]["median_house_value"]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.loc[df["median_income"] < 2,"median_house_value"]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %% [markdown]
# 3. Показать данные в первых 2 столбцах

# %%
df[["longitude", "latitude"]]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.columns[:2] # узнаем название всех колонок в таблице.в данном случае покажет первые 2 колонки
# Out:
# Index(['longitude', 'latitude'], dtype='object')

# %%
df[df.columns[:2]] # выводит данные указанных колонок
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
# после ":" пишем сколько строк вывести, а потом уазываем какие столбцы вывести.loc - выдает данные по названию столбца
df.loc[:5,["longitude", "latitude"]]
# Out:
#    longitude  latitude
# 0    -122.05     37.37
# 1    -118.30     34.26
# 2    -117.81     33.78
# 3    -118.36     33.82
# 4    -119.67     36.33
# 5    -119.56     36.51

# %%
df.loc[:, : "latitude"] # от начала и до столбика Латитьюд
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.iloc[:, : 2] # выдает не по имени столбца, а по индексу столбца. в данном случает от начала и до 2го столбца
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %% [markdown]
# 4. Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df[(df["housing_median_age"] < 20) & (df["median_house_value"] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# # Задача №61.
# # 1. Определить какое максимальное и минимальное значение median_house_value

# %%
df["median_house_value"].min(), df["median_house_value"].max()
# Out:
# (22500.0, 500001.0)

# %%
# чтобы включился кортеж, нужно вконце поставить запятую
123, 678, 234, 89876532
# Out:
# (123, 678, 234, 89876532)

# %%
987654, # если нужно получить одно значение
# Out:
# (987654,)

# %%
# для целоцисленого
(987654)
# Out:
# 987654

# %% [markdown]
# # 2. Показать максимальное median_house_value, где median_income = 3.1250

# %%
df[df["median_income"] ==3.1250]["median_house_value"].max() #1.выводим строки, которые удовлетворяют этому условию ==31250,а потом пишем, где ищем
# Out:
# 233300.0

# %% [markdown]
# # 3. Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
df["median_house_value"].min()  #нашли минимум
# Out:
# 22500.0

# %%
df[df['median_house_value'] == df["median_house_value"].min()]["population"].max()
# Out:
# 1230.0
